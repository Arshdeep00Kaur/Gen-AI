# %% [markdown]
# ## Text Preprocessing
#
# Raw text data is often noisy and unstructured, containing various inconsistencies such as typos, slang, abbreviations, and irrelevant information. Preprocessing helps in:
#
# Improving Data Quality: Removing noise and irrelevant information ensures that the data fed into the model is clean and consistent.
# Enhancing Model Performance: Well-preprocessed text can lead to better feature extraction, improving the performance of NLP models.
# Reducing Complexity: Simplifying the text data can reduce the computational complexity and make the models more efficient.

# %%
corpus = [
    "I'm so excited about the party tonight! 🎉🥳",
    "Just finished a great workout 💪 feeling tired but happy 😊",
    "Can't believe we won the game! ⚽️🏆 What an amazing match! 👏",
    "The sunset was beautiful today 🌅 nature is amazing ❤️",
    "Working from home today with my cat 🐱 and coffee ☕",
    "This movie made me cry 😭 but the ending was perfect 👌"
]

# %%
import pandas as pd

# %%
df = pd.DataFrame(corpus,columns=['text'])

# %%
df
# Out:
#                                                 text
# 0         I'm so excited about the party tonight! 🎉🥳
# 1  Just finished a great workout 💪 feeling tired ...
# 2  Can't believe we won the game! ⚽️🏆 What an ama...
# 3  The sunset was beautiful today 🌅 nature is ama...
# 4  Working from home today with my cat 🐱 and coff...
# 5  This movie made me cry 😭 but the ending was pe...

# %%
df['LowerCase']=df['text'].str.lower()

# %%
df
# Out:
#                                                 text                                          LowerCase
# 0         I'm so excited about the party tonight! 🎉🥳         i'm so excited about the party tonight! 🎉🥳
# 1  Just finished a great workout 💪 feeling tired ...  just finished a great workout 💪 feeling tired ...
# 2  Can't believe we won the game! ⚽️🏆 What an ama...  can't believe we won the game! ⚽️🏆 what an ama...
# 3  The sunset was beautiful today 🌅 nature is ama...  the sunset was beautiful today 🌅 nature is ama...
# 4  Working from home today with my cat 🐱 and coff...  working from home today with my cat 🐱 and coff...
# 5  This movie made me cry 😭 but the ending was pe...  this movie made me cry 😭 but the ending was pe...

# %%
# pip install emoji

# Import necessary libraries
import emoji
import string
import re

# Apply transformations in sequence
df['cleanText'] = df['LowerCase'].apply(lambda x: emoji.replace_emoji(x, ' '))                    # Remove emojis
df['cleanText'] = df['cleanText'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))  # Remove punctuation
df['cleanText'] = df['cleanText'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())                # Remove extra whitespace

# Display cleaned DataFrame
df
# Out:
#                                                 text  ...                                          cleanText
# 0         I'm so excited about the party tonight! 🎉🥳  ...              im so excited about the party tonight
# 1  Just finished a great workout 💪 feeling tired ...  ...  just finished a great workout feeling tired bu...
# 2  Can't believe we won the game! ⚽️🏆 What an ama...  ...  cant believe we won the game what an amazing m...
# 3  The sunset was beautiful today 🌅 nature is ama...  ...   the sunset was beautiful today nature is amazing
# 4  Working from home today with my cat 🐱 and coff...  ...     working from home today with my cat and coffee
# 5  This movie made me cry 😭 but the ending was pe...  ...  this movie made me cry but the ending was perfect
#
# [6 rows x 3 columns]

# %%
## stopwords

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords=set(stopwords.words('english'))

# %%
df['NoStopWords']=df['cleanText'].apply(lambda x: ' '.join(word for word in x.split() if word not in stopwords))

# %%
df
# Out:
#                                                 text  ...                                 NoStopWords
# 0         I'm so excited about the party tonight! 🎉🥳  ...                    im excited party tonight
# 1  Just finished a great workout 💪 feeling tired ...  ...  finished great workout feeling tired happy
# 2  Can't believe we won the game! ⚽️🏆 What an ama...  ...             cant believe game amazing match
# 3  The sunset was beautiful today 🌅 nature is ama...  ...       sunset beautiful today nature amazing
# 4  Working from home today with my cat 🐱 and coff...  ...               working home today cat coffee
# 5  This movie made me cry 😭 but the ending was pe...  ...               movie made cry ending perfect
#
# [6 rows x 4 columns]

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()
df['Stemmed']=df['NoStopWords'].apply(lambda x: ' '.join(ps.stem(word)for word in x.split()))

# %%
df
# Out:
#                                                 text  ...                               Stemmed
# 0         I'm so excited about the party tonight! 🎉🥳  ...                im excit parti tonight
# 1  Just finished a great workout 💪 feeling tired ...  ...  finish great workout feel tire happi
# 2  Can't believe we won the game! ⚽️🏆 What an ama...  ...           cant believ game amaz match
# 3  The sunset was beautiful today 🌅 nature is ama...  ...        sunset beauti today natur amaz
# 4  Working from home today with my cat 🐱 and coff...  ...             work home today cat coffe
# 5  This movie made me cry 😭 but the ending was pe...  ...             movi made cri end perfect
#
# [6 rows x 5 columns]
